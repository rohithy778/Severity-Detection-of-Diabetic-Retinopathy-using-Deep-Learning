# %%
from zipfile import ZipFile
file_name = "/content/12.zip"

with ZipFile(file_name,'r') as openZip:
  openZip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
file_name = "/content/13.zip"

with ZipFile(file_name,'r') as openZip:
  openZip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
file_name = "/content/14.zip"

with ZipFile(file_name,'r') as openZip:
  openZip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
file_name = "/content/train_11_12.zip"

with ZipFile(file_name,'r') as openZip:
  openZip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
file_name = "/content/train_21_22.zip"

with ZipFile(file_name,'r') as openZip:
  openZip.extractall()
  print('Done')
# Out:
# Done

# %%
from zipfile import ZipFile
file_name = "/content/train_23_24.zip"

with ZipFile(file_name,'r') as openZip:
  openZip.extractall()
  print('Done')
# Out:
# Done

# %%
import pandas as pd
from glob import glob
import tensorflow as tf

# %%
train_path = '/content/train_11_12'
test_path = '/content/13'


train_Impath = glob(train_path+'/*.tif')
test_Impath = glob(test_path+'/*.tif')
df = pd.DataFrame(train_Impath, columns = ['filepath'])
df3 = pd.DataFrame(test_Impath, columns = ['filepath'])

# %%
train_path2 = '/content/14'

train_Impath2 = glob(train_path2+'/*.tif')
df5 = pd.DataFrame(train_Impath2, columns = ['filepath'])
df5.head()
# Out:
#                                  filepath
# 0  /content/14/20060529_56563_0100_PP.tif
# 1  /content/14/20060530_55816_0100_PP.tif
# 2  /content/14/20060530_54718_0100_PP.tif
# 3  /content/14/20060530_53761_0100_PP.tif
# 4  /content/14/20060529_56853_0100_PP.tif

# %%
train_path = '/content/train_21_22'

train_Impath = glob(train_path+'/*.tif')
df7 = pd.DataFrame(train_Impath, columns = ['filepath'])

# %%
train_path = '/content/train_23_24'

train_Impath = glob(train_path+'/*.tif')
df9 = pd.DataFrame(train_Impath, columns = ['filepath'])

# %%
df9.head()
# Out:
#                                           filepath
# 0  /content/train_23_24/20060411_58469_0200_PP.tif
# 1  /content/train_23_24/20060411_61687_0200_PP.tif
# 2  /content/train_23_24/20060411_59176_0200_PP.tif
# 3  /content/train_23_24/20060412_59636_0200_PP.tif
# 4  /content/train_23_24/20060412_60978_0200_PP.tif

# %%
df.head()
# Out:
#                                           filepath
# 0  /content/train_11_12/20051021_59459_0100_PP.tif
# 1  /content/train_11_12/20051214_57230_0100_PP.tif
# 2  /content/train_11_12/20051020_44762_0100_PP.tif
# 3  /content/train_11_12/20051020_54209_0100_PP.tif
# 4  /content/train_11_12/20051214_51733_0100_PP.tif

# %%
df3.head()
# Out:
#                                  filepath
# 0  /content/13/20060523_43196_0100_PP.tif
# 1  /content/13/20060522_43643_0100_PP.tif
# 2  /content/13/20060523_48357_0100_PP.tif
# 3  /content/13/20060523_48591_0100_PP.tif
# 4  /content/13/20060523_48102_0100_PP.tif

# %%
df2 = pd.read_excel(r"/content/train_11_12.xlsx")
df4 = pd.read_excel(r"/content/Annotation_Base13.xls")

# %%
df6 = pd.read_excel(r"/content/Annotation Base14.xls")

# %%
df8 = pd.read_excel(r"/content/21_22.xlsx")

# %%
df10 = pd.read_excel(r"/content/23_24.xlsx")

# %%
df2.columns
# Out:
# Index(['Image name', 'Ophthalmologic department', 'Retinopathy grade',
#        'Risk of macular edema '],
#       dtype='object')

# %%
df4['Retinopathy grade'][0]
# Out:
# 3

# %%
def fun(a):
    return str(a)

# %%
df['Retinopathy_grade'] = df2['Retinopathy grade'].apply(fun)
df3['Retinopathy_grade'] = df4['Retinopathy grade'].apply(fun)

# %%
df5['Retinopathy_grade'] = df6['Retinopathy grade'].apply(fun)

# %%
df7['Retinopathy_grade'] = df8['Retinopathy grade'].apply(fun)

# %%
df9['Retinopathy_grade'] = df10['Retinopathy grade'].apply(fun)

# %%
df9.head()
# Out:
#                                           filepath Retinopathy_grade
# 0  /content/train_23_24/20060411_58469_0200_PP.tif                 3
# 1  /content/train_23_24/20060411_61687_0200_PP.tif                 1
# 2  /content/train_23_24/20060411_59176_0200_PP.tif                 1
# 3  /content/train_23_24/20060412_59636_0200_PP.tif                 1
# 4  /content/train_23_24/20060412_60978_0200_PP.tif                 0

# %%
df = pd.concat([df, df5, df7, df9])

# %%
df_train = df.copy()
df_test = df3.copy()
df_train.head()
# Out:
#                                           filepath Retinopathy_grade
# 0  /content/train_11_12/20051021_59459_0100_PP.tif                 3
# 1  /content/train_11_12/20051214_57230_0100_PP.tif                 0
# 2  /content/train_11_12/20051020_44762_0100_PP.tif                 1
# 3  /content/train_11_12/20051020_54209_0100_PP.tif                 2
# 4  /content/train_11_12/20051214_51733_0100_PP.tif                 3

# %%
df_test.head()
# Out:
#                                  filepath Retinopathy_grade
# 0  /content/13/20060523_43196_0100_PP.tif                 3
# 1  /content/13/20060522_43643_0100_PP.tif                 3
# 2  /content/13/20060523_48357_0100_PP.tif                 2
# 3  /content/13/20060523_48591_0100_PP.tif                 0
# 4  /content/13/20060523_48102_0100_PP.tif                 0

# %%
tf.random.set_seed(42)

# %%
Epochs = 5
Img_size = 512
Batch_size = 32

classes = {0 : "No DR",
           1 : "Mild DR",
           2 : "Severe DR",
           3 : "Proliferate DR"}

# %%
datagen = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1./255,
                                                         validation_split = 0.1)
# datagen = tf.keras.preprocessing.image.ImageDataGenerator( rescale = 1./255,
#                                                           rotation_range = 0.2,
#                                                           shear_range = 0.2,
#                                                           zoom_range = 0.2,
#                                                           width_shift_range = 0.2,
#                                                           height_shift_range = 0.3,
#                                                          horizontal_flip = True,
#                                                          validation_split = 0.1)

# %%
train_gen = datagen.flow_from_dataframe(dataframe = df_train,
                                   x_col = 'filepath',
                                   y_col = 'Retinopathy_grade',
                                   subset = 'training',
                                   seed = 1,
                                   batch_size = Batch_size,
                                   color_mode = 'rgb',
                                   shuffle = True,
                                   class_mode = 'categorical',
                                   target_size = (Img_size, Img_size))

valid_gen = datagen.flow_from_dataframe(dataframe = df_train,
                                   x_col = 'filepath',
                                   y_col = 'Retinopathy_grade',
                                   subset = 'validation',
                                   seed = 1,
                                   batch_size = Batch_size,
                                   color_mode = 'rgb',
                                   shuffle = False,
                                   class_mode = 'categorical',
                                   target_size = (Img_size, Img_size))

test_gen = datagen.flow_from_dataframe(dataframe = df_test,
                                      x_col = 'filepath',
                                      y_col = 'Retinopathy_grade',
                                      batch_size = Batch_size,
                                      seed = 1,
                                      color_mode = 'rgb',
                                      shuffle = False,
                                      class_mode = None,
                                      target_size = (Img_size, Img_size))
# Out:
# Found 630 validated image filenames belonging to 4 classes.
# Found 70 validated image filenames belonging to 4 classes.
# Found 100 validated image filenames.

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, Activation
from tensorflow.keras import Sequential

# %%
model_1 = Sequential([
    Conv2D(10, 3, input_shape=(512, 512, 3), activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Flatten(),
    Dense(4, activation = 'softmax')
])

# %%
model_1.compile(loss = tf.keras.losses.categorical_crossentropy,
                optimizer = Adam(),
                metrics = ['accuracy'])

# %%
step_size_train = train_gen.n//train_gen.batch_size
step_size_valid = valid_gen.n//valid_gen.batch_size

# %%
history_1 = model_1.fit(train_gen,
            steps_per_epoch = step_size_train,
            validation_data = valid_gen,
            validation_steps = step_size_valid,
            epochs = 15)
# Out:
# Epoch 1/15
# 19/19 [==============================] - 23s 1s/step - loss: 1.4595 - accuracy: 0.3528 - val_loss: 1.3449 - val_accuracy: 0.3125
# Epoch 2/15
# 19/19 [==============================] - 19s 985ms/step - loss: 1.2727 - accuracy: 0.4331 - val_loss: 1.2876 - val_accuracy: 0.4531
# Epoch 3/15
# 19/19 [==============================] - 17s 868ms/step - loss: 1.2466 - accuracy: 0.4415 - val_loss: 1.2582 - val_accuracy: 0.4531
# Epoch 4/15
# 19/19 [==============================] - 19s 1s/step - loss: 1.2484 - accuracy: 0.4448 - val_loss: 1.3362 - val_accuracy: 0.4062
# Epoch 5/15
# 19/19 [==============================] - 17s 893ms/step - loss: 1.2278 - accuracy: 0.4666 - val_loss: 1.2915 - val_accuracy: 0.4219
# Epoch 6/15
# 19/19 [==============================] - 17s 868ms/step - loss: 1.2111 - accuracy: 0.4615 - val_loss: 1.2618 - val_accuracy: 0.4219
# Epoch 7/15
# ...

# %%
import matplotlib.pyplot as plt

# %%
def plot_loss_curves(history):
  """
  Returns seperate loss curves for training and validation metrics
  """
  loss = history.history["loss"]
  val_loss = history.history["val_loss"]

  accuracy = history.history["accuracy"]
  val_accuracy = history.history["val_accuracy"]

  epochs = range(len(history.history["loss"]))

  #plot loss
  plt.plot(epochs, loss, label = "training loss")
  plt.plot(epochs, val_loss, label = "val_loss")
  plt.title("loss")
  plt.xlabel("epochs")
  plt.legend()

  plt.figure()
  #plot accuracy
  plt.plot(epochs, accuracy, label = "training accuracy")
  plt.plot(epochs, val_accuracy, label = "val_accuracy")
  plt.title("accuracy")
  plt.xlabel("epochs")
  plt.legend()

# %%
plot_loss_curves(history_1)

# %%
model_2 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters = 10,
                           kernel_size = 3,
                           activation = "relu",
                           input_shape = (512,512,3)),
    tf.keras.layers.Conv2D(10, 3, activation = 'relu'),
    tf.keras.layers.MaxPool2D(pool_size = 2,
                              padding = "valid"),
    tf.keras.layers.Conv2D(10, 3, activation = "relu"),
    tf.keras.layers.Conv2D(10, 3, activation = "relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4, activation = "softmax")
])

model_2.compile(loss= tf.keras.losses.categorical_crossentropy,
                optimizer=tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

history_2 = model_2.fit(x = train_gen,
            steps_per_epoch = step_size_train,
            validation_data = valid_gen,
            validation_steps = step_size_valid,
            epochs = 30)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 19s 893ms/step - loss: 1.9410 - accuracy: 0.3438 - val_loss: 1.4153 - val_accuracy: 0.2812
# Epoch 2/30
# 19/19 [==============================] - 19s 992ms/step - loss: 1.3164 - accuracy: 0.4181 - val_loss: 1.2942 - val_accuracy: 0.3906
# Epoch 3/30
# 19/19 [==============================] - 18s 960ms/step - loss: 1.2958 - accuracy: 0.4482 - val_loss: 1.3730 - val_accuracy: 0.2812
# Epoch 4/30
# 19/19 [==============================] - 20s 1s/step - loss: 1.2693 - accuracy: 0.4548 - val_loss: 1.2945 - val_accuracy: 0.3438
# Epoch 5/30
# 19/19 [==============================] - 16s 864ms/step - loss: 1.2332 - accuracy: 0.4615 - val_loss: 1.3006 - val_accuracy: 0.3906
# Epoch 6/30
# 19/19 [==============================] - 16s 867ms/step - loss: 1.1901 - accuracy: 0.4849 - val_loss: 1.2805 - val_accuracy: 0.4531
# Epoch 7/30
# ...

# %%
plot_loss_curves(history_2)

# %%
model_6 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters = 10,
                           kernel_size = 3,
                           activation = "relu",
                           input_shape = (512,512,3)),
    tf.keras.layers.Conv2D(10, 5, activation = 'relu'),
    tf.keras.layers.MaxPool2D(pool_size = 2,
                              padding = "valid"),
    tf.keras.layers.Conv2D(10, 5, activation = "relu"),
    tf.keras.layers.Conv2D(10, 5, activation = "relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4, activation = "tanh")
])

model_6.compile(loss= tf.keras.losses.binary_crossentropy,
                optimizer=tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

history_6 = model_6.fit(x = train_gen,
            steps_per_epoch = step_size_train,
            validation_data = valid_gen,
            validation_steps = step_size_valid,
            epochs = 30)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 22s 987ms/step - loss: 1.8776 - accuracy: 0.3512 - val_loss: 1.4107 - val_accuracy: 0.2969
# Epoch 2/30
# 19/19 [==============================] - 17s 872ms/step - loss: 0.6409 - accuracy: 0.2642 - val_loss: 0.5340 - val_accuracy: 0.4531
# Epoch 3/30
# 19/19 [==============================] - 17s 867ms/step - loss: 0.5500 - accuracy: 0.3294 - val_loss: 0.5500 - val_accuracy: 0.3125
# Epoch 4/30
# 19/19 [==============================] - 20s 1s/step - loss: 0.5298 - accuracy: 0.4231 - val_loss: 0.5318 - val_accuracy: 0.2969
# Epoch 5/30
# 19/19 [==============================] - 16s 860ms/step - loss: 1.1304 - accuracy: 0.2676 - val_loss: 0.9191 - val_accuracy: 0.4531
# Epoch 6/30
# 19/19 [==============================] - 17s 885ms/step - loss: 0.9948 - accuracy: 0.4112 - val_loss: 0.9624 - val_accuracy: 0.2969
# Epoch 7/30
# ...

# %%
plot_loss_curves(history_6)

# %%
model3 = Sequential([
    Conv2D(10, 3, input_shape = (512, 512, 3), activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Flatten(),
    Dense(4, activation = 'sigmoid')
])

# %%
model3.compile(loss = tf.losses.categorical_crossentropy,
              optimizer = Adam(),
              metrics = ['accuracy'])

# %%
history_3 = model3.fit(train_gen,
                       steps_per_epoch = step_size_train,
                       validation_data = valid_gen,
                       validation_steps = step_size_valid,
                       epochs = 30)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 24s 969ms/step - loss: 1.3454 - accuracy: 0.4147 - val_loss: 1.3941 - val_accuracy: 0.2969
# Epoch 2/30
# 19/19 [==============================] - 17s 897ms/step - loss: 1.3180 - accuracy: 0.4164 - val_loss: 1.3513 - val_accuracy: 0.2969
# Epoch 3/30
# 19/19 [==============================] - 16s 855ms/step - loss: 1.3207 - accuracy: 0.4145 - val_loss: 1.3278 - val_accuracy: 0.2969
# Epoch 4/30
# 19/19 [==============================] - 19s 1s/step - loss: 1.2901 - accuracy: 0.4264 - val_loss: 1.3386 - val_accuracy: 0.2969
# Epoch 5/30
# 19/19 [==============================] - 16s 864ms/step - loss: 1.2924 - accuracy: 0.4247 - val_loss: 1.3617 - val_accuracy: 0.2969
# Epoch 6/30
# 19/19 [==============================] - 17s 879ms/step - loss: 1.2959 - accuracy: 0.4348 - val_loss: 1.3022 - val_accuracy: 0.2969
# Epoch 7/30
# ...

# %%
model3.summary()
# Out:
# Model: "sequential_37"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_205 (Conv2D)         (None, 510, 510, 10)      280
#
#  conv2d_206 (Conv2D)         (None, 508, 508, 10)      910
#
#  max_pooling2d_92 (MaxPoolin  (None, 254, 254, 10)     0
#  g2D)
#
#  conv2d_207 (Conv2D)         (None, 252, 252, 10)      910
#
#  conv2d_208 (Conv2D)         (None, 250, 250, 10)      910
#
#  max_pooling2d_93 (MaxPoolin  (None, 125, 125, 10)     0
#  g2D)
#
#  conv2d_209 (Conv2D)         (None, 123, 123, 10)      910
#
#  conv2d_210 (Conv2D)         (None, 121, 121, 10)      910
#
#  conv2d_211 (Conv2D)         (None, 119, 119, 10)      910
#
#  max_pooling2d_94 (MaxPoolin  (None, 59, 59, 10)       0
#  g2D)
#
#  conv2d_212 (Conv2D)         (None, 57, 57, 10)        910
#
#  conv2d_213 (Conv2D)         (None, 55, 55, 10)        910
#
#  conv2d_214 (Conv2D)         (None, 53, 53, 10)        910
#
# ...

# %%
plot_loss_curves(history_3)

# %%
model7 = Sequential([
    Conv2D(10, 3, input_shape = (512, 512, 3), activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Flatten(),
    Dense(4, activation = 'sigmoid')
])

# %%
model7.compile(loss = tf.losses.categorical_crossentropy,
              optimizer = Adam(),
              metrics = ['accuracy'])

# %%
history_7 = model3.fit(train_gen,
                       steps_per_epoch = step_size_train,
                       validation_data = valid_gen,
                       validation_steps = step_size_valid,
                       epochs = 30)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 18s 965ms/step - loss: 1.1912 - accuracy: 0.4916 - val_loss: 1.4050 - val_accuracy: 0.3281
# Epoch 2/30
# 19/19 [==============================] - 16s 859ms/step - loss: 1.1795 - accuracy: 0.5017 - val_loss: 1.3858 - val_accuracy: 0.4375
# Epoch 3/30
# 19/19 [==============================] - 17s 878ms/step - loss: 1.1758 - accuracy: 0.4967 - val_loss: 1.3908 - val_accuracy: 0.3594
# Epoch 4/30
# 19/19 [==============================] - 16s 864ms/step - loss: 1.1599 - accuracy: 0.4983 - val_loss: 1.4034 - val_accuracy: 0.3438
# Epoch 5/30
# 19/19 [==============================] - 17s 878ms/step - loss: 1.1356 - accuracy: 0.5050 - val_loss: 1.4359 - val_accuracy: 0.3594
# Epoch 6/30
# 19/19 [==============================] - 17s 876ms/step - loss: 1.1534 - accuracy: 0.5217 - val_loss: 1.3525 - val_accuracy: 0.3125
# Epoch 7/30
# ...

# %%
plot_loss_curves(history_7)

# %%
model4 = Sequential([
    Conv2D(10, 5, input_shape = (512, 512, 3), activation = 'relu'),
    Conv2D(100, 5, activation = 'relu'),
    MaxPool2D(4),
    Conv2D(100, 5, activation = 'relu'),
    Flatten(),
    Dense(4, activation = 'softmax')
])

# %%
model4.summary()
# Out:
# Model: "sequential_47"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_275 (Conv2D)         (None, 508, 508, 10)      760
#
#  conv2d_276 (Conv2D)         (None, 504, 504, 100)     25100
#
#  max_pooling2d_122 (MaxPooli  (None, 126, 126, 100)    0
#  ng2D)
#
#  conv2d_277 (Conv2D)         (None, 122, 122, 100)     250100
#
#  flatten_47 (Flatten)        (None, 1488400)           0
#
#  dense_49 (Dense)            (None, 4)                 5953604
#
# ...
# Total params: 6,229,564
# Trainable params: 6,229,564
# Non-trainable params: 0
# _________________________________________________________________

# %%
model4.compile(loss = tf.losses.categorical_crossentropy,
              optimizer = Adam(),
              metrics = ['accuracy'])

# %%
history_4 = model4.fit(train_gen,
                       steps_per_epoch = step_size_train,
                       validation_data = valid_gen,
                       validation_steps = step_size_valid,
                       epochs = 30)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 20s 1s/step - loss: 1.2332 - accuracy: 0.4649 - val_loss: 1.2664 - val_accuracy: 0.3906
# Epoch 2/30
# 19/19 [==============================] - 19s 973ms/step - loss: 1.2320 - accuracy: 0.4498 - val_loss: 1.2755 - val_accuracy: 0.3906
# Epoch 3/30
# 19/19 [==============================] - 20s 1s/step - loss: 1.2275 - accuracy: 0.4582 - val_loss: 1.2787 - val_accuracy: 0.4219
# Epoch 4/30
# 19/19 [==============================] - 19s 981ms/step - loss: 1.2314 - accuracy: 0.4632 - val_loss: 1.2693 - val_accuracy: 0.4062
# Epoch 5/30
# 19/19 [==============================] - 19s 1s/step - loss: 1.2197 - accuracy: 0.4582 - val_loss: 1.2652 - val_accuracy: 0.4375
# Epoch 6/30
# 19/19 [==============================] - 19s 994ms/step - loss: 1.2286 - accuracy: 0.4682 - val_loss: 1.3420 - val_accuracy: 0.4062
# Epoch 7/30
# ...

# %%
plot_loss_curves(history_4)

# %%
model8 = Sequential([
    Conv2D(10, 3, input_shape = (512, 512, 3), activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(100, 3, activation = 'relu'),
    Conv2D(100, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(75, 3, activation = 'relu'),
    Conv2D(75, 3, activation = 'relu'),
    Conv2D(75, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(50, 3, activation = 'relu'),
    Conv2D(50, 3, activation = 'relu'),
    Conv2D(50, 3, activation = 'relu'),
    MaxPool2D(),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    Conv2D(10, 3, activation = 'relu'),
    MaxPool2D(),
    Flatten(),
    Dense(10, activation = 'softmax'),
    Dense(4, activation = 'sigmoid')
])

# %%
model8.compile(loss = tf.losses.categorical_crossentropy,
              optimizer = Adam(),
              metrics = ['accuracy'])

# %%
history_8 = model8.fit(train_gen,
                       steps_per_epoch = step_size_train,
                       validation_data = valid_gen,
                       validation_steps = step_size_valid,
                       epochs = 30)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 34s 2s/step - loss: 1.3319 - accuracy: 0.4214 - val_loss: 1.3382 - val_accuracy: 0.2969
# Epoch 2/30
# 19/19 [==============================] - 19s 967ms/step - loss: 1.3162 - accuracy: 0.4181 - val_loss: 1.3521 - val_accuracy: 0.2969
# Epoch 3/30
# 19/19 [==============================] - 19s 992ms/step - loss: 1.3111 - accuracy: 0.4181 - val_loss: 1.3485 - val_accuracy: 0.2969
# Epoch 4/30
# 19/19 [==============================] - 19s 1s/step - loss: 1.3147 - accuracy: 0.4130 - val_loss: 1.3603 - val_accuracy: 0.2969
# Epoch 5/30
# 19/19 [==============================] - 19s 983ms/step - loss: 1.3091 - accuracy: 0.4161 - val_loss: 1.3631 - val_accuracy: 0.2969
# Epoch 6/30
# 19/19 [==============================] - 19s 968ms/step - loss: 1.3056 - accuracy: 0.4214 - val_loss: 1.3379 - val_accuracy: 0.2969
# Epoch 7/30
# ...

# %%
plot_loss_curves(history_8)

# %%
model_1.save("model1.h5")
model_2.save("model2.h5")
model3.save("model3.h5")
model4.save("model4.h5")
model_6.save("model6.h5")
model7.save("model7.h5")
model8.save("model8.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-194-5f18e5d179bb> in <cell line: 1>()
# ----> 1 model1.save("model_1.h5")
#       2 model2.save("model_2.h5")
#       3 model3.save("model3.h5")
#       4 model4.save("model4.h5")
#       5 model6.save("model_6.h5")
#
# NameError: name 'model1' is not defined

# %%
model_1.save("model1.h5")
model_2.save("model2.h5")

# %%
model3.save("model3.h5")

# %%
model_2.save("model2_2.h5")

# %%
model4.save("model4.h5")
model_6.save("model6.h5")
model7.save("model7.h5")
model8.save("model8.h5")

# %%
model_9 = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters = 10,
                           kernel_size = 3,
                           activation = "relu",
                           input_shape = (512,512,3)),
    tf.keras.layers.Conv2D(10, 3, activation = 'relu'),
    tf.keras.layers.MaxPool2D(pool_size = 2,
                              padding = "valid"),
    tf.keras.layers.Conv2D(10, 3, activation = "relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Conv2D(10, 3, activation = "relu"),
    tf.keras.layers.MaxPool2D(2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4, activation = "softmax")
])

model_9.compile(loss= tf.keras.losses.categorical_crossentropy,
                optimizer=tf.keras.optimizers.Adam(),
                metrics = ['accuracy'])

history_9 = model_9.fit(x = train_gen,
            steps_per_epoch = step_size_train,
            validation_data = valid_gen,
            validation_steps = step_size_valid,
            epochs = 30)
# Out:
# Epoch 1/30
# 19/19 [==============================] - 21s 938ms/step - loss: 1.3968 - accuracy: 0.3428 - val_loss: 1.3437 - val_accuracy: 0.2969
# Epoch 2/30
# 19/19 [==============================] - 16s 850ms/step - loss: 1.2883 - accuracy: 0.4231 - val_loss: 1.2915 - val_accuracy: 0.2812
# Epoch 3/30
# 19/19 [==============================] - 16s 848ms/step - loss: 1.2809 - accuracy: 0.4247 - val_loss: 1.3055 - val_accuracy: 0.2969
# Epoch 4/30
# 19/19 [==============================] - 17s 898ms/step - loss: 1.2602 - accuracy: 0.4532 - val_loss: 1.2630 - val_accuracy: 0.4219
# Epoch 5/30
# 19/19 [==============================] - 16s 838ms/step - loss: 1.2510 - accuracy: 0.4431 - val_loss: 1.2621 - val_accuracy: 0.4531
# Epoch 6/30
# 19/19 [==============================] - 16s 853ms/step - loss: 1.2458 - accuracy: 0.4548 - val_loss: 1.2734 - val_accuracy: 0.4531
# Epoch 7/30
# ...

# %%
! gdown --id 1SH-FxDdAttVzz9miiSinxbdTSdtWw-x4
# Out:
# /usr/local/lib/python3.9/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1SH-FxDdAttVzz9miiSinxbdTSdtWw-x4
# To: /content/train.zip
# 100% 3.04G/3.04G [00:44<00:00, 67.7MB/s]
